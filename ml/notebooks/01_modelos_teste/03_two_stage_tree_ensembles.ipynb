# %% [markdown]
# # Notebook 3 - Modelos Baseados em Arvores
#
# Pipeline two-stage com Random Forest como modelo principal e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
UTILS_DIR = next(
    (candidate / "utils" for candidate in [NOTEBOOK_DIR, *NOTEBOOK_DIR.parents] if (candidate / "utils").is_dir()),
    None,
)
if UTILS_DIR is None:
    raise RuntimeError("Nao encontrei ml/notebooks/utils. Execute o notebook dentro do repositorio Saltim.")
sys.path.insert(0, str(UTILS_DIR))

from sklearn.ensemble import (
    GradientBoostingClassifier,
    GradientBoostingRegressor,
    RandomForestClassifier,
    RandomForestRegressor,
)
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
threshold_models = {
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

purchase_alert_models = {
    "Random Forest Classifier": RandomForestClassifier(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

# %%
results = run_training_notebook(
    notebook_id="03_tree_ensembles",
    family="Arvores",
    threshold_models=threshold_models,
    purchase_alert_models=purchase_alert_models,
)

display(results["threshold_metrics"])
display(results["purchase_alert_metrics"])
display(results["criticality_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "criticality_rates", "feature_count"]])
# Out:
# 2026/05/29 10:19:14 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_threshold_regression_random_forest_regressor' already exists. Creating a new version of this model...
# 2026/05/29 10:19:17 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_threshold_regression_random_forest_regressor, version 2
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_threshold_regression_random_forest_regressor'.
# 🏃 View run 03_tree_ensembles - threshold_regression - Random Forest Regressor at: http://localhost:5000/#/experiments/23/runs/a8a30d7e5b80486f9288e75dd7d2242e
# 🧪 View experiment at: http://localhost:5000/#/experiments/23
# 2026/05/29 10:19:26 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_threshold_regression_xgboost_regressor' already exists. Creating a new version of this model...
# 2026/05/29 10:19:28 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_threshold_regression_xgboost_regressor, version 2
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_threshold_regression_xgboost_regressor'.
# 🏃 View run 03_tree_ensembles - threshold_regression - XGBoost Regressor at: http://localhost:5000/#/experiments/23/runs/4f20fde6854640ef9c26b55be30d8af9
# 🧪 View experiment at: http://localhost:5000/#/experiments/23
# 2026/05/29 10:20:11 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_threshold_regression_gradient_boosting_regressor' already exists. Creating a new version of this model...
# 2026/05/29 10:20:14 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_threshold_regression_gradient_boosting_regressor, version 2
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_threshold_regression_gradient_boosting_regressor'.
# 🏃 View run 03_tree_ensembles - threshold_regression - Gradient Boosting Regressor at: http://localhost:5000/#/experiments/23/runs/27d6e7bd81f54ea8b52e51ce6ed6bc1a
# 🧪 View experiment at: http://localhost:5000/#/experiments/23
# 2026/05/29 10:20:21 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_random_forest_classifier' already exists. Creating a new version of this model...
# 2026/05/29 10:20:23 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_purchase_alert_classification_random_forest_classifier, version 2
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_random_forest_classifier'.
# 🏃 View run 03_tree_ensembles - purchase_alert_classification - Random Forest Classifier at: http://localhost:5000/#/experiments/24/runs/50486c6cf6ef4050bb465bb8888a0a81
# 🧪 View experiment at: http://localhost:5000/#/experiments/24
# 2026/05/29 10:20:27 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_xgboost_classifier' already exists. Creating a new version of this model...
# 2026/05/29 10:20:30 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_purchase_alert_classification_xgboost_classifier, version 2
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_xgboost_classifier'.
# 🏃 View run 03_tree_ensembles - purchase_alert_classification - XGBoost Classifier at: http://localhost:5000/#/experiments/24/runs/8ef094e762b34fb293e9917c1ad2d321
# 🧪 View experiment at: http://localhost:5000/#/experiments/24
# 2026/05/29 10:21:13 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Registered model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_gradient_boosting_classifier' already exists. Creating a new version of this model...
# 2026/05/29 10:21:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_03_tree_ensembles_purchase_alert_classification_gradient_boosting_classifier, version 2
# 🏃 View run 03_tree_ensembles - purchase_alert_classification - Gradient Boosting Classifier at: http://localhost:5000/#/experiments/24/runs/d0c2092912a74b31bac9c3dea9205d51
# 🧪 View experiment at: http://localhost:5000/#/experiments/24
# Created version '2' of model 'saltim_two_stage_03_tree_ensembles_purchase_alert_classification_gradient_boosting_classifier'.
#             notebook   family                 stage  \
# 0  03_tree_ensembles  Arvores  threshold_regression
# 1  03_tree_ensembles  Arvores  threshold_regression
# 2  03_tree_ensembles  Arvores  threshold_regression
#
#                          model  accuracy  balanced_accuracy  f1_macro  \
# 0      Random Forest Regressor  0.998856           0.998191  0.997815
# 1            XGBoost Regressor  0.997999           0.997306  0.996182
# 2  Gradient Boosting Regressor  0.997856           0.995711  0.995898
#
#    precision_macro  recall_macro   taxa_ok  ...  average_precision      rmse  \
# 0         0.997440      0.998191  0.845032  ...                NaN  0.046589
# 1         0.995066      0.997306  0.844460  ...                NaN  0.046804
# 2         0.996086      0.995711  0.845461  ...                NaN  0.051189
#
#         mae        r2                            run_id  \
# 0  0.035292  0.778663  a8a30d7e5b80486f9288e75dd7d2242e
# 1  0.035411  0.776620  4f20fde6854640ef9c26b55be30d8af9
# 2  0.038615  0.732801  27d6e7bd81f54ea8b52e51ce6ed6bc1a
#
#                                       model_uri  \
# 0  runs:/a8a30d7e5b80486f9288e75dd7d2242e/model
# 1  runs:/4f20fde6854640ef9c26b55be30d8af9/model
# 2  runs:/27d6e7bd81f54ea8b52e51ce6ed6bc1a/model
#
#                                 metric_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_reg...
# 1  evaluation/03_tree_ensembles_xgboost_regressor...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
#
#                             prediction_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_reg...
# 1  evaluation/03_tree_ensembles_xgboost_regressor...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
#
#                            summary_artifact_path  \
# 0  evaluation/03_tree_ensembles_run_summary.json
# 1  evaluation/03_tree_ensembles_run_summary.json
# 2  evaluation/03_tree_ensembles_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_03_tree_ensembles_threshold_r...
# 1  saltim_two_stage_03_tree_ensembles_threshold_r...
# 2  saltim_two_stage_03_tree_ensembles_threshold_r...
#
# [3 rows x 24 columns]
#             notebook   family                          stage  \
# 0  03_tree_ensembles  Arvores  purchase_alert_classification
# 1  03_tree_ensembles  Arvores  purchase_alert_classification
# 2  03_tree_ensembles  Arvores  purchase_alert_classification
#
#                           model  accuracy  balanced_accuracy  f1_macro  \
# 0      Random Forest Classifier  0.997856           0.995711  0.995898
# 1            XGBoost Classifier  0.997570           0.994409  0.995345
# 2  Gradient Boosting Classifier  0.997570           0.996297  0.995362
#
#    precision_macro  recall_macro   taxa_ok  ...  average_precision  rmse mae  \
# 0         0.996086      0.995711  0.845461  ...           0.999708   NaN NaN
# 1         0.996285      0.994409  0.846033  ...           0.999782   NaN NaN
# 2         0.994432      0.996297  0.844603  ...           0.994169   NaN NaN
#
#    r2                            run_id  \
# 0 NaN  50486c6cf6ef4050bb465bb8888a0a81
# 1 NaN  8ef094e762b34fb293e9917c1ad2d321
# 2 NaN  d0c2092912a74b31bac9c3dea9205d51
#
#                                       model_uri  \
# 0  runs:/50486c6cf6ef4050bb465bb8888a0a81/model
# 1  runs:/8ef094e762b34fb293e9917c1ad2d321/model
# 2  runs:/d0c2092912a74b31bac9c3dea9205d51/model
#
#                                 metric_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_cla...
# 1  evaluation/03_tree_ensembles_xgboost_classifie...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
#
#                             prediction_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_cla...
# 1  evaluation/03_tree_ensembles_xgboost_classifie...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
#
#                            summary_artifact_path  \
# 0  evaluation/03_tree_ensembles_run_summary.json
# 1  evaluation/03_tree_ensembles_run_summary.json
# 2  evaluation/03_tree_ensembles_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_03_tree_ensembles_purchase_al...
# 1  saltim_two_stage_03_tree_ensembles_purchase_al...
# 2  saltim_two_stage_03_tree_ensembles_purchase_al...
#
# [3 rows x 24 columns]
#             notebook   family                          stage  \
# 0  03_tree_ensembles  Arvores           threshold_regression
# 1  03_tree_ensembles  Arvores           threshold_regression
# 2  03_tree_ensembles  Arvores           threshold_regression
# 3  03_tree_ensembles  Arvores  purchase_alert_classification
# 4  03_tree_ensembles  Arvores  purchase_alert_classification
# 5  03_tree_ensembles  Arvores  purchase_alert_classification
#
#                           model  accuracy  balanced_accuracy  f1_macro  \
# 0       Random Forest Regressor  0.998856           0.998191  0.997815
# 1             XGBoost Regressor  0.997999           0.997306  0.996182
# 2   Gradient Boosting Regressor  0.997856           0.995711  0.995898
# 3      Random Forest Classifier  0.997856           0.995711  0.995898
# 4            XGBoost Classifier  0.997570           0.994409  0.995345
# 5  Gradient Boosting Classifier  0.997570           0.996297  0.995362
#
#    precision_macro  recall_macro   taxa_ok  ...  average_precision      rmse  \
# 0         0.997440      0.998191  0.845032  ...                NaN  0.046589
# 1         0.995066      0.997306  0.844460  ...                NaN  0.046804
# 2         0.996086      0.995711  0.845461  ...                NaN  0.051189
# 3         0.996086      0.995711  0.845461  ...           0.999708       NaN
# 4         0.996285      0.994409  0.846033  ...           0.999782       NaN
# 5         0.994432      0.996297  0.844603  ...           0.994169       NaN
#
#         mae        r2                            run_id  \
# 0  0.035292  0.778663  a8a30d7e5b80486f9288e75dd7d2242e
# 1  0.035411  0.776620  4f20fde6854640ef9c26b55be30d8af9
# 2  0.038615  0.732801  27d6e7bd81f54ea8b52e51ce6ed6bc1a
# 3       NaN       NaN  50486c6cf6ef4050bb465bb8888a0a81
# 4       NaN       NaN  8ef094e762b34fb293e9917c1ad2d321
# 5       NaN       NaN  d0c2092912a74b31bac9c3dea9205d51
#
#                                       model_uri  \
# 0  runs:/a8a30d7e5b80486f9288e75dd7d2242e/model
# 1  runs:/4f20fde6854640ef9c26b55be30d8af9/model
# 2  runs:/27d6e7bd81f54ea8b52e51ce6ed6bc1a/model
# 3  runs:/50486c6cf6ef4050bb465bb8888a0a81/model
# 4  runs:/8ef094e762b34fb293e9917c1ad2d321/model
# 5  runs:/d0c2092912a74b31bac9c3dea9205d51/model
#
#                                 metric_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_reg...
# 1  evaluation/03_tree_ensembles_xgboost_regressor...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
# 3  evaluation/03_tree_ensembles_random_forest_cla...
# 4  evaluation/03_tree_ensembles_xgboost_classifie...
# 5  evaluation/03_tree_ensembles_gradient_boosting...
#
#                             prediction_artifact_path  \
# 0  evaluation/03_tree_ensembles_random_forest_reg...
# 1  evaluation/03_tree_ensembles_xgboost_regressor...
# 2  evaluation/03_tree_ensembles_gradient_boosting...
# 3  evaluation/03_tree_ensembles_random_forest_cla...
# 4  evaluation/03_tree_ensembles_xgboost_classifie...
# 5  evaluation/03_tree_ensembles_gradient_boosting...
#
#                            summary_artifact_path  \
# 0  evaluation/03_tree_ensembles_run_summary.json
# 1  evaluation/03_tree_ensembles_run_summary.json
# 2  evaluation/03_tree_ensembles_run_summary.json
# 3  evaluation/03_tree_ensembles_run_summary.json
# 4  evaluation/03_tree_ensembles_run_summary.json
# 5  evaluation/03_tree_ensembles_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_03_tree_ensembles_threshold_r...
# 1  saltim_two_stage_03_tree_ensembles_threshold_r...
# 2  saltim_two_stage_03_tree_ensembles_threshold_r...
# 3  saltim_two_stage_03_tree_ensembles_purchase_al...
# 4  saltim_two_stage_03_tree_ensembles_purchase_al...
# 5  saltim_two_stage_03_tree_ensembles_purchase_al...
#
# [6 rows x 24 columns]
#             notebook   family  sample_shape  \
# 0  03_tree_ensembles  Arvores  [61750, 105]
#
#                                         split_counts  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...
#
#                                    criticality_rates  feature_count
# 0  {'OK': 0.8442753036437247, 'Alerta de compra':...             73
