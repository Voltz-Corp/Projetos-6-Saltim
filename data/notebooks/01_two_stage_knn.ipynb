# %% [markdown]
# # Notebook 1 - Algoritmos Baseados em Distancia
#
# Pipeline two-stage com KNN como modelo principal e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "two_stage_common.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str((Path("data") / "notebooks").resolve()))

from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
threshold_models = {
    "KNN Regressor": KNeighborsRegressor(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

purchase_alert_models = {
    "KNN Classifier": KNeighborsClassifier(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

# %%
results = run_training_notebook(
    notebook_id="01_knn",
    family="Distancia",
    threshold_models=threshold_models,
    purchase_alert_models=purchase_alert_models,
)

display(results["threshold_metrics"])
display(results["purchase_alert_metrics"])
display(results["criticality_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "criticality_rates", "feature_count"]])
# Out:
# 2026/05/28 22:07:21 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:07:22 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_threshold_regression_knn_regressor'.
# 2026/05/28 22:07:26 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_threshold_regression_knn_regressor, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_threshold_regression_knn_regressor'.
# 🏃 View run 01_knn - threshold_regression - KNN Regressor at: http://localhost:5000/#/experiments/1/runs/5085995423e14c0b94e45d097b63bcfe
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/05/28 22:07:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:07:34 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_threshold_regression_xgboost_regressor'.
# 2026/05/28 22:07:37 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_threshold_regression_xgboost_regressor, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_threshold_regression_xgboost_regressor'.
# 🏃 View run 01_knn - threshold_regression - XGBoost Regressor at: http://localhost:5000/#/experiments/1/runs/cf81e8afccb7422783d611895d0d8306
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/05/28 22:08:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:08:21 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_threshold_regression_gradient_boosting_regressor'.
# 2026/05/28 22:08:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_threshold_regression_gradient_boosting_regressor, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_threshold_regression_gradient_boosting_regressor'.
# 🏃 View run 01_knn - threshold_regression - Gradient Boosting Regressor at: http://localhost:5000/#/experiments/1/runs/68f0c3f2a0b24d1a86d175374a38add9
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/05/28 22:08:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:08:29 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_purchase_alert_classification_knn_classifier'.
# 2026/05/28 22:08:32 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_purchase_alert_classification_knn_classifier, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_purchase_alert_classification_knn_classifier'.
# 🏃 View run 01_knn - purchase_alert_classification - KNN Classifier at: http://localhost:5000/#/experiments/3/runs/b7e8371478564b35bb9681424a15dfa8
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 2026/05/28 22:08:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:08:36 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_purchase_alert_classification_xgboost_classifier'.
# 2026/05/28 22:08:40 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_purchase_alert_classification_xgboost_classifier, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_purchase_alert_classification_xgboost_classifier'.
# 🏃 View run 01_knn - purchase_alert_classification - XGBoost Classifier at: http://localhost:5000/#/experiments/3/runs/a49ea1d8757f4717ad9191d5c7dee2a2
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 2026/05/28 22:09:27 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/28 22:09:27 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Successfully registered model 'saltim_two_stage_01_knn_purchase_alert_classification_gradient_boosting_classifier'.
# 2026/05/28 22:09:30 INFO mlflow.store.model_registry.abstract_store: Waiting up to 120 seconds for model version to finish creation. Model name: saltim_two_stage_01_knn_purchase_alert_classification_gradient_boosting_classifier, version 1
# Created version '1' of model 'saltim_two_stage_01_knn_purchase_alert_classification_gradient_boosting_classifier'.
# 🏃 View run 01_knn - purchase_alert_classification - Gradient Boosting Classifier at: http://localhost:5000/#/experiments/3/runs/4885776f19be4bc48c7e13410a22ee8d
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
#   notebook     family                 stage                        model  \
# 0   01_knn  Distancia  threshold_regression                KNN Regressor
# 1   01_knn  Distancia  threshold_regression            XGBoost Regressor
# 2   01_knn  Distancia  threshold_regression  Gradient Boosting Regressor
#
#    accuracy  balanced_accuracy  f1_macro  precision_macro  recall_macro  \
# 0  0.993567           0.986379  0.987667         0.988967      0.986379
# 1  0.997999           0.997306  0.996182         0.995066      0.997306
# 2  0.997856           0.995711  0.995898         0.996086      0.995711
#
#     taxa_ok  ...  average_precision      rmse       mae        r2  \
# 0  0.846319  ...                NaN  0.071022  0.048211  0.485638
# 1  0.844460  ...                NaN  0.046804  0.035411  0.776620
# 2  0.845461  ...                NaN  0.051190  0.038618  0.732790
#
#                              run_id  \
# 0  5085995423e14c0b94e45d097b63bcfe
# 1  cf81e8afccb7422783d611895d0d8306
# 2  68f0c3f2a0b24d1a86d175374a38add9
#
#                                       model_uri  \
# 0  runs:/5085995423e14c0b94e45d097b63bcfe/model
# 1  runs:/cf81e8afccb7422783d611895d0d8306/model
# 2  runs:/68f0c3f2a0b24d1a86d175374a38add9/model
#
#                                 metric_artifact_path  \
# 0  evaluation/01_knn_knn_regressor_threshold_regr...
# 1  evaluation/01_knn_xgboost_regressor_threshold_...
# 2  evaluation/01_knn_gradient_boosting_regressor_...
#
#                             prediction_artifact_path  \
# 0  evaluation/01_knn_knn_regressor_threshold_regr...
# 1  evaluation/01_knn_xgboost_regressor_threshold_...
# 2  evaluation/01_knn_gradient_boosting_regressor_...
#
#                 summary_artifact_path  \
# 0  evaluation/01_knn_run_summary.json
# 1  evaluation/01_knn_run_summary.json
# 2  evaluation/01_knn_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_01_knn_threshold_regression_k...
# 1  saltim_two_stage_01_knn_threshold_regression_x...
# 2  saltim_two_stage_01_knn_threshold_regression_g...
#
# [3 rows x 24 columns]
#   notebook     family                          stage  \
# 0   01_knn  Distancia  purchase_alert_classification
# 1   01_knn  Distancia  purchase_alert_classification
# 2   01_knn  Distancia  purchase_alert_classification
#
#                           model  accuracy  balanced_accuracy  f1_macro  \
# 0                KNN Classifier  0.982988           0.959356  0.966934
# 1            XGBoost Classifier  0.997570           0.994409  0.995345
# 2  Gradient Boosting Classifier  0.997570           0.996297  0.995362
#
#    precision_macro  recall_macro   taxa_ok  ...  average_precision  rmse mae  \
# 0         0.974913      0.959356  0.851465  ...           0.969034   NaN NaN
# 1         0.996285      0.994409  0.846033  ...           0.999782   NaN NaN
# 2         0.994432      0.996297  0.844603  ...           0.994169   NaN NaN
#
#    r2                            run_id  \
# 0 NaN  b7e8371478564b35bb9681424a15dfa8
# 1 NaN  a49ea1d8757f4717ad9191d5c7dee2a2
# 2 NaN  4885776f19be4bc48c7e13410a22ee8d
#
#                                       model_uri  \
# 0  runs:/b7e8371478564b35bb9681424a15dfa8/model
# 1  runs:/a49ea1d8757f4717ad9191d5c7dee2a2/model
# 2  runs:/4885776f19be4bc48c7e13410a22ee8d/model
#
#                                 metric_artifact_path  \
# 0  evaluation/01_knn_knn_classifier_purchase_aler...
# 1  evaluation/01_knn_xgboost_classifier_purchase_...
# 2  evaluation/01_knn_gradient_boosting_classifier...
#
#                             prediction_artifact_path  \
# 0  evaluation/01_knn_knn_classifier_purchase_aler...
# 1  evaluation/01_knn_xgboost_classifier_purchase_...
# 2  evaluation/01_knn_gradient_boosting_classifier...
#
#                 summary_artifact_path  \
# 0  evaluation/01_knn_run_summary.json
# 1  evaluation/01_knn_run_summary.json
# 2  evaluation/01_knn_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_01_knn_purchase_alert_classif...
# 1  saltim_two_stage_01_knn_purchase_alert_classif...
# 2  saltim_two_stage_01_knn_purchase_alert_classif...
#
# [3 rows x 24 columns]
#   notebook     family                          stage  \
# 0   01_knn  Distancia           threshold_regression
# 1   01_knn  Distancia           threshold_regression
# 2   01_knn  Distancia           threshold_regression
# 3   01_knn  Distancia  purchase_alert_classification
# 4   01_knn  Distancia  purchase_alert_classification
# 5   01_knn  Distancia  purchase_alert_classification
#
#                           model  accuracy  balanced_accuracy  f1_macro  \
# 0                 KNN Regressor  0.993567           0.986379  0.987667
# 1             XGBoost Regressor  0.997999           0.997306  0.996182
# 2   Gradient Boosting Regressor  0.997856           0.995711  0.995898
# 3                KNN Classifier  0.982988           0.959356  0.966934
# 4            XGBoost Classifier  0.997570           0.994409  0.995345
# 5  Gradient Boosting Classifier  0.997570           0.996297  0.995362
#
#    precision_macro  recall_macro   taxa_ok  ...  average_precision      rmse  \
# 0         0.988967      0.986379  0.846319  ...                NaN  0.071022
# 1         0.995066      0.997306  0.844460  ...                NaN  0.046804
# 2         0.996086      0.995711  0.845461  ...                NaN  0.051190
# 3         0.974913      0.959356  0.851465  ...           0.969034       NaN
# 4         0.996285      0.994409  0.846033  ...           0.999782       NaN
# 5         0.994432      0.996297  0.844603  ...           0.994169       NaN
#
#         mae        r2                            run_id  \
# 0  0.048211  0.485638  5085995423e14c0b94e45d097b63bcfe
# 1  0.035411  0.776620  cf81e8afccb7422783d611895d0d8306
# 2  0.038618  0.732790  68f0c3f2a0b24d1a86d175374a38add9
# 3       NaN       NaN  b7e8371478564b35bb9681424a15dfa8
# 4       NaN       NaN  a49ea1d8757f4717ad9191d5c7dee2a2
# 5       NaN       NaN  4885776f19be4bc48c7e13410a22ee8d
#
#                                       model_uri  \
# 0  runs:/5085995423e14c0b94e45d097b63bcfe/model
# 1  runs:/cf81e8afccb7422783d611895d0d8306/model
# 2  runs:/68f0c3f2a0b24d1a86d175374a38add9/model
# 3  runs:/b7e8371478564b35bb9681424a15dfa8/model
# 4  runs:/a49ea1d8757f4717ad9191d5c7dee2a2/model
# 5  runs:/4885776f19be4bc48c7e13410a22ee8d/model
#
#                                 metric_artifact_path  \
# 0  evaluation/01_knn_knn_regressor_threshold_regr...
# 1  evaluation/01_knn_xgboost_regressor_threshold_...
# 2  evaluation/01_knn_gradient_boosting_regressor_...
# 3  evaluation/01_knn_knn_classifier_purchase_aler...
# 4  evaluation/01_knn_xgboost_classifier_purchase_...
# 5  evaluation/01_knn_gradient_boosting_classifier...
#
#                             prediction_artifact_path  \
# 0  evaluation/01_knn_knn_regressor_threshold_regr...
# 1  evaluation/01_knn_xgboost_regressor_threshold_...
# 2  evaluation/01_knn_gradient_boosting_regressor_...
# 3  evaluation/01_knn_knn_classifier_purchase_aler...
# 4  evaluation/01_knn_xgboost_classifier_purchase_...
# 5  evaluation/01_knn_gradient_boosting_classifier...
#
#                 summary_artifact_path  \
# 0  evaluation/01_knn_run_summary.json
# 1  evaluation/01_knn_run_summary.json
# 2  evaluation/01_knn_run_summary.json
# 3  evaluation/01_knn_run_summary.json
# 4  evaluation/01_knn_run_summary.json
# 5  evaluation/01_knn_run_summary.json
#
#                                registered_model_name
# 0  saltim_two_stage_01_knn_threshold_regression_k...
# 1  saltim_two_stage_01_knn_threshold_regression_x...
# 2  saltim_two_stage_01_knn_threshold_regression_g...
# 3  saltim_two_stage_01_knn_purchase_alert_classif...
# 4  saltim_two_stage_01_knn_purchase_alert_classif...
# 5  saltim_two_stage_01_knn_purchase_alert_classif...
#
# [6 rows x 24 columns]
#   notebook     family  sample_shape  \
# 0   01_knn  Distancia  [61750, 105]
#
#                                         split_counts  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...
#
#                                    criticality_rates  feature_count
# 0  {'OK': 0.8442753036437247, 'Alerta de compra':...             73
