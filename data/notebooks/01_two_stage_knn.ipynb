# %% [markdown]
# # Notebook 1 - Algoritmos Baseados em Distancia
#
# Pipeline two-stage com KNN como modelo principal e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "two_stage_common.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str((Path("data") / "notebooks").resolve()))

from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
classifiers = {
    "KNN Classifier": KNeighborsClassifier(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

regressors = {
    "KNN Regressor": KNeighborsRegressor(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

# %%
results = run_training_notebook(
    notebook_id="01_knn",
    family="Distancia",
    classifiers=classifiers,
    regressors=regressors,
)

display(results["classification_metrics"])
display(results["regression_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "positive_rate", "feature_count"]])
# Out:
#   notebook     family           stage                         model  \
# 0   01_knn  Distancia  classification                KNN Classifier
# 1   01_knn  Distancia  classification            XGBoost Classifier
# 2   01_knn  Distancia  classification  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/01_knn_knn_classifier_c...
# 1  ml/artifacts/two_stage/01_knn_xgboost_classifi...
# 2  ml/artifacts/two_stage/01_knn_gradient_boostin...
#
#                                      prediction_path  f1_score  precision  \
# 0  ml/artifacts/two_stage/metrics/01_knn_knn_clas...  0.869863   0.884737
# 1  ml/artifacts/two_stage/metrics/01_knn_xgboost_...  0.947876   0.932977
# 2  ml/artifacts/two_stage/metrics/01_knn_gradient...  0.955515   0.950879
#
#      recall  accuracy   roc_auc warnings
# 0  0.855481  0.940243  0.962208
# 1  0.963258  0.975268  0.996241
# 2  0.960196  0.979128  0.996355
#   notebook     family       stage                        model  \
# 0   01_knn  Distancia  regression                KNN Regressor
# 1   01_knn  Distancia  regression            XGBoost Regressor
# 2   01_knn  Distancia  regression  Gradient Boosting Regressor
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/01_knn_knn_regressor_re...
# 1  ml/artifacts/two_stage/01_knn_xgboost_regresso...
# 2  ml/artifacts/two_stage/01_knn_gradient_boostin...
#
#                                      prediction_path       rmse        mae  \
# 0  ml/artifacts/two_stage/metrics/01_knn_knn_regr...  98.581844  14.787691
# 1  ml/artifacts/two_stage/metrics/01_knn_xgboost_...  84.369323  11.155200
# 2  ml/artifacts/two_stage/metrics/01_knn_gradient...  70.554901  10.866622
#
#          r2 warnings
# 0  0.804910
# 1  0.857107
# 2  0.900070
#   notebook     family  sample_shape  \
# 0   01_knn  Distancia  [61750, 101]
#
#                                         split_counts  positive_rate  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...         0.2543
#
#    feature_count
# 0             73
