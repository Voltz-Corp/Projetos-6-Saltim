# %% [markdown]
# # Notebook 2 - Modelos Lineares
#
# Pipeline two-stage com Regressao Logistica no Stage 1, Regressao Linear no Stage 2 e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "two_stage_common.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str((Path("data") / "notebooks").resolve()))

from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

regressors = {
    "Linear Regression": LinearRegression(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

# %%
results = run_training_notebook(
    notebook_id="02_linear",
    family="Linear",
    classifiers=classifiers,
    regressors=regressors,
)

display(results["classification_metrics"])
display(results["regression_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "positive_rate", "feature_count"]])
# Out:
#     notebook  family           stage                         model  \
# 0  02_linear  Linear  classification           Logistic Regression
# 1  02_linear  Linear  classification            XGBoost Classifier
# 2  02_linear  Linear  classification  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/02_linear_logistic_regr...
# 1  ml/artifacts/two_stage/02_linear_xgboost_class...
# 2  ml/artifacts/two_stage/02_linear_gradient_boos...
#
#                                      prediction_path  f1_score  precision  \
# 0  ml/artifacts/two_stage/metrics/02_linear_logis...  0.864078   0.916266
# 1  ml/artifacts/two_stage/metrics/02_linear_xgboo...  0.947876   0.932977
# 2  ml/artifacts/two_stage/metrics/02_linear_gradi...  0.955515   0.950879
#
#      recall  accuracy   roc_auc  \
# 0  0.817514  0.939957  0.983442
# 1  0.963258  0.975268  0.996241
# 2  0.960196  0.979128  0.996366
#
#                                             warnings
# 0  ConvergenceWarning: lbfgs failed to converge a...
# 1
# 2
#     notebook  family       stage                        model  \
# 0  02_linear  Linear  regression            Linear Regression
# 1  02_linear  Linear  regression            XGBoost Regressor
# 2  02_linear  Linear  regression  Gradient Boosting Regressor
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/02_linear_linear_regres...
# 1  ml/artifacts/two_stage/02_linear_xgboost_regre...
# 2  ml/artifacts/two_stage/02_linear_gradient_boos...
#
#                                      prediction_path       rmse        mae  \
# 0  ml/artifacts/two_stage/metrics/02_linear_linea...  91.849960  16.470480
# 1  ml/artifacts/two_stage/metrics/02_linear_xgboo...  84.369323  11.155200
# 2  ml/artifacts/two_stage/metrics/02_linear_gradi...  71.221524  10.884353
#
#          r2 warnings
# 0  0.830644
# 1  0.857107
# 2  0.898173
#     notebook  family  sample_shape  \
# 0  02_linear  Linear  [61750, 101]
#
#                                         split_counts  positive_rate  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...         0.2543
#
#    feature_count
# 0             73
