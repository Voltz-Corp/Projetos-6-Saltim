# %% [markdown]
# # Notebook 2 - Modelos Lineares
#
# Pipeline two-stage com Regressao Logistica no Stage 1, Regressao Linear no Stage 2 e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "two_stage_common.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str((Path("data") / "notebooks").resolve()))

from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
threshold_models = {
    "Linear Regression": LinearRegression(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

purchase_alert_models = {
    "Logistic Regression": LogisticRegression(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

# %%
results = run_training_notebook(
    notebook_id="02_linear",
    family="Linear",
    threshold_models=threshold_models,
    purchase_alert_models=purchase_alert_models,
)

display(results["threshold_metrics"])
display(results["purchase_alert_metrics"])
display(results["criticality_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "criticality_rates", "feature_count"]])
# Out:
#     notebook  family                 stage                        model  \
# 0  02_linear  Linear  threshold_regression            Linear Regression
# 1  02_linear  Linear  threshold_regression            XGBoost Regressor
# 2  02_linear  Linear  threshold_regression  Gradient Boosting Regressor
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/02_linear_linear_regres...
# 1  ml/artifacts/two_stage/02_linear_xgboost_regre...
# 2  ml/artifacts/two_stage/02_linear_gradient_boos...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/02_linear_linea...  0.995568  0.991523
# 1  ml/artifacts/two_stage/metrics/02_linear_xgboo...  0.997999  0.996182
# 2  ml/artifacts/two_stage/metrics/02_linear_gradi...  0.997856  0.995898
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.991709      0.991338  0.845461            0.154539
# 1         0.995066      0.997306  0.844460            0.155540
# 2         0.996086      0.995711  0.845461            0.154539
#
#    taxa_necessita_compra warnings      rmse       mae        r2
# 0               0.154539           0.083430  0.057833  0.290209
# 1               0.155540           0.046804  0.035411  0.776620
# 2               0.154539           0.051189  0.038615  0.732801
#     notebook  family                          stage  \
# 0  02_linear  Linear  purchase_alert_classification
# 1  02_linear  Linear  purchase_alert_classification
# 2  02_linear  Linear  purchase_alert_classification
#
#                           model  \
# 0           Logistic Regression
# 1            XGBoost Classifier
# 2  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/02_linear_logistic_regr...
# 1  ml/artifacts/two_stage/02_linear_xgboost_class...
# 2  ml/artifacts/two_stage/02_linear_gradient_boos...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/02_linear_logis...  0.985132  0.972056
# 1  ml/artifacts/two_stage/metrics/02_linear_xgboo...  0.997570  0.995345
# 2  ml/artifacts/two_stage/metrics/02_linear_gradi...  0.997570  0.995362
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.964284      0.980257  0.838742            0.161258
# 1         0.996285      0.994409  0.846033            0.153967
# 2         0.994432      0.996297  0.844603            0.155397
#
#    taxa_necessita_compra warnings  rmse  mae  r2
# 0               0.161258            NaN  NaN NaN
# 1               0.153967            NaN  NaN NaN
# 2               0.155397            NaN  NaN NaN
#     notebook  family                          stage  \
# 0  02_linear  Linear           threshold_regression
# 1  02_linear  Linear           threshold_regression
# 2  02_linear  Linear           threshold_regression
# 3  02_linear  Linear  purchase_alert_classification
# 4  02_linear  Linear  purchase_alert_classification
# 5  02_linear  Linear  purchase_alert_classification
#
#                           model  \
# 0             Linear Regression
# 1             XGBoost Regressor
# 2   Gradient Boosting Regressor
# 3           Logistic Regression
# 4            XGBoost Classifier
# 5  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/02_linear_linear_regres...
# 1  ml/artifacts/two_stage/02_linear_xgboost_regre...
# 2  ml/artifacts/two_stage/02_linear_gradient_boos...
# 3  ml/artifacts/two_stage/02_linear_logistic_regr...
# 4  ml/artifacts/two_stage/02_linear_xgboost_class...
# 5  ml/artifacts/two_stage/02_linear_gradient_boos...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/02_linear_linea...  0.995568  0.991523
# 1  ml/artifacts/two_stage/metrics/02_linear_xgboo...  0.997999  0.996182
# 2  ml/artifacts/two_stage/metrics/02_linear_gradi...  0.997856  0.995898
# 3  ml/artifacts/two_stage/metrics/02_linear_logis...  0.985132  0.972056
# 4  ml/artifacts/two_stage/metrics/02_linear_xgboo...  0.997570  0.995345
# 5  ml/artifacts/two_stage/metrics/02_linear_gradi...  0.997570  0.995362
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.991709      0.991338  0.845461            0.154539
# 1         0.995066      0.997306  0.844460            0.155540
# 2         0.996086      0.995711  0.845461            0.154539
# 3         0.964284      0.980257  0.838742            0.161258
# 4         0.996285      0.994409  0.846033            0.153967
# 5         0.994432      0.996297  0.844603            0.155397
#
#    taxa_necessita_compra warnings      rmse       mae        r2
# 0               0.154539           0.083430  0.057833  0.290209
# 1               0.155540           0.046804  0.035411  0.776620
# 2               0.154539           0.051189  0.038615  0.732801
# 3               0.161258                NaN       NaN       NaN
# 4               0.153967                NaN       NaN       NaN
# 5               0.155397                NaN       NaN       NaN
#     notebook  family  sample_shape  \
# 0  02_linear  Linear  [61750, 105]
#
#                                         split_counts  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...
#
#                                    criticality_rates  feature_count
# 0  {'OK': 0.8442753036437247, 'Alerta de compra':...             73
