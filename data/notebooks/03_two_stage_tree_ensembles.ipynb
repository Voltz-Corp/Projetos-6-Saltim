# %% [markdown]
# # Notebook 3 - Modelos Baseados em Arvores
#
# Pipeline two-stage com Random Forest como modelo principal e XGBoost/Gradient Boosting como baselines.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "two_stage_common.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str((Path("data") / "notebooks").resolve()))

from sklearn.ensemble import (
    GradientBoostingClassifier,
    GradientBoostingRegressor,
    RandomForestClassifier,
    RandomForestRegressor,
)
from xgboost import XGBClassifier, XGBRegressor

from two_stage_common import run_training_notebook

# %%
threshold_models = {
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBoost Regressor": XGBRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
}

purchase_alert_models = {
    "Random Forest Classifier": RandomForestClassifier(),
    "XGBoost Classifier": XGBClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
}

# %%
results = run_training_notebook(
    notebook_id="03_tree_ensembles",
    family="Arvores",
    threshold_models=threshold_models,
    purchase_alert_models=purchase_alert_models,
)

display(results["threshold_metrics"])
display(results["purchase_alert_metrics"])
display(results["criticality_metrics"])
display(results["summary"][["notebook", "family", "sample_shape", "split_counts", "criticality_rates", "feature_count"]])
# Out:
#             notebook   family                 stage  \
# 0  03_tree_ensembles  Arvores  threshold_regression
# 1  03_tree_ensembles  Arvores  threshold_regression
# 2  03_tree_ensembles  Arvores  threshold_regression
#
#                          model  \
# 0      Random Forest Regressor
# 1            XGBoost Regressor
# 2  Gradient Boosting Regressor
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/03_tree_ensembles_rando...
# 1  ml/artifacts/two_stage/03_tree_ensembles_xgboo...
# 2  ml/artifacts/two_stage/03_tree_ensembles_gradi...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.998713  0.997543
# 1  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997999  0.996182
# 2  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997856  0.995898
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.996981      0.998106  0.844889            0.155111
# 1         0.995066      0.997306  0.844460            0.155540
# 2         0.996086      0.995711  0.845461            0.154539
#
#    taxa_necessita_compra warnings      rmse       mae        r2
# 0               0.155111           0.046893  0.035387  0.775765
# 1               0.155540           0.046804  0.035411  0.776620
# 2               0.154539           0.051190  0.038618  0.732790
#             notebook   family                          stage  \
# 0  03_tree_ensembles  Arvores  purchase_alert_classification
# 1  03_tree_ensembles  Arvores  purchase_alert_classification
# 2  03_tree_ensembles  Arvores  purchase_alert_classification
#
#                           model  \
# 0      Random Forest Classifier
# 1            XGBoost Classifier
# 2  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/03_tree_ensembles_rando...
# 1  ml/artifacts/two_stage/03_tree_ensembles_xgboo...
# 2  ml/artifacts/two_stage/03_tree_ensembles_gradi...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997999  0.996173
# 1  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997570  0.995345
# 2  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997570  0.995362
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.996173      0.996173  0.845318            0.154682
# 1         0.996285      0.994409  0.846033            0.153967
# 2         0.994432      0.996297  0.844603            0.155397
#
#    taxa_necessita_compra warnings  rmse  mae  r2
# 0               0.154682            NaN  NaN NaN
# 1               0.153967            NaN  NaN NaN
# 2               0.155397            NaN  NaN NaN
#             notebook   family                          stage  \
# 0  03_tree_ensembles  Arvores           threshold_regression
# 1  03_tree_ensembles  Arvores           threshold_regression
# 2  03_tree_ensembles  Arvores           threshold_regression
# 3  03_tree_ensembles  Arvores  purchase_alert_classification
# 4  03_tree_ensembles  Arvores  purchase_alert_classification
# 5  03_tree_ensembles  Arvores  purchase_alert_classification
#
#                           model  \
# 0       Random Forest Regressor
# 1             XGBoost Regressor
# 2   Gradient Boosting Regressor
# 3      Random Forest Classifier
# 4            XGBoost Classifier
# 5  Gradient Boosting Classifier
#
#                                        artifact_path  \
# 0  ml/artifacts/two_stage/03_tree_ensembles_rando...
# 1  ml/artifacts/two_stage/03_tree_ensembles_xgboo...
# 2  ml/artifacts/two_stage/03_tree_ensembles_gradi...
# 3  ml/artifacts/two_stage/03_tree_ensembles_rando...
# 4  ml/artifacts/two_stage/03_tree_ensembles_xgboo...
# 5  ml/artifacts/two_stage/03_tree_ensembles_gradi...
#
#                                      prediction_path  accuracy  f1_macro  \
# 0  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.998713  0.997543
# 1  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997999  0.996182
# 2  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997856  0.995898
# 3  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997999  0.996173
# 4  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997570  0.995345
# 5  ml/artifacts/two_stage/metrics/03_tree_ensembl...  0.997570  0.995362
#
#    precision_macro  recall_macro   taxa_ok  taxa_alerta_compra  \
# 0         0.996981      0.998106  0.844889            0.155111
# 1         0.995066      0.997306  0.844460            0.155540
# 2         0.996086      0.995711  0.845461            0.154539
# 3         0.996173      0.996173  0.845318            0.154682
# 4         0.996285      0.994409  0.846033            0.153967
# 5         0.994432      0.996297  0.844603            0.155397
#
#    taxa_necessita_compra warnings      rmse       mae        r2
# 0               0.155111           0.046893  0.035387  0.775765
# 1               0.155540           0.046804  0.035411  0.776620
# 2               0.154539           0.051190  0.038618  0.732790
# 3               0.154682                NaN       NaN       NaN
# 4               0.153967                NaN       NaN       NaN
# 5               0.155397                NaN       NaN       NaN
#             notebook   family  sample_shape  \
# 0  03_tree_ensembles  Arvores  [61750, 105]
#
#                                         split_counts  \
# 0  {'train': 45480, 'validation': 9275, 'test': 6...
#
#                                    criticality_rates  feature_count
# 0  {'OK': 0.8442753036437247, 'Alerta de compra':...             73
